# %% [markdown]
# ### Changelog
#
# - Separating **process_iplist()** output from VT calls to folders (todays_date)
# - changed output of **process_json()** FROM "_parsed-combined" to todays_date_parsed-combined in EACH RESPECTIVE FOLDER

# %% [markdown]
# ### Flow
#
# 1. User edits and feeds ip.csv
# 2. **process_iplist()** reads each and calls VT api
# 3. Responses are stored in **"downloaded_vtresponse"** and seperated into folders by **respective dates** (DDMMYYYY)
# 4. **process_json()** reads jsons in each folder and generates a compilation for that day in each folder

# %% [markdown]
# ### Questions / Todo List
#
# **Update**
#
# I have managed to get the scripts running from jupyter notebook but have the following questions
#
# (a) Receiving (via a web interface) either an individual or list of domais / IP addresses --> currently it's fed via CSV, should i create a front-end for people to upload their files?
#
# (b) Storing list of domains / IP address into a queue based list --> Is this the back-end of things? That is to say, this script runs in the back-end and whenever files come in from front-end it'll trigger the script?
#
# (c) Carryout enrichment --> Where does this "processed in the previous X days" come from? From what i understand, should i create a check such that when new information comes in, it will look at previous histories when the IP/Domain was checked, and continue / stop accordingly?
#
# (d) storing responses in disk and extracting subset into DB --> is there a specific subset you'd like? DB-wise I would prefer to try NoSQL as i have no experience with it!

# %%
import base64
import hashlib
import json
import requests
import time
import csv
import datetime
import os
import pandas as pd
from dateutil import tz
import pytz
from pymongo import MongoClient


json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

# API_KEY = '0d9fdb6e32d74b9d12e3d894309531838c3aabe8d66b049fd3a7976fbedf2c68'  #@param  {type: "string"}
API_KEY = '207349263f9c5edd176cc079fa8000a5ab912df7d9e91154842c08031658675d'  #@param  {type: "string"}



client = MongoClient('localhost',27017)
# db = client['d_ip_enrich']
db = client['filtered_sg_ip_list_day1']
    


def process_iplist(filename_to_process, columnIndex, x_days_ago):
    
    print("======= process_iplist() START =======")
    
    # TODO: Make generalised and incorporate timestamp in foldername
    now = datetime.datetime.now()
#     dt_string = now.strftime("%d%m%Y")
    dt_string = now.strftime("%Y%m%d")
    d = datetime.timedelta(days = x_days_ago)
#     deducted_date = (now - d).strftime("%d%m%Y")
    deducted_date = (now - d).strftime("%Y%m%d")
    
    with open(filename_to_process + ".csv", newline='') as inputfile:

        if not os.path.exists("downloaded_vtresponse"):
                os.makedirs("downloaded_vtresponse")

        with open(filename_to_process + "_tracker_" + dt_string + ".csv", 'w', newline='') as outputfile:
            
            ip_list = csv.reader(inputfile, delimiter=',')
            output_writer = csv.writer(outputfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

            counter = 0

            for row in ip_list:
                
                if counter == 0:
                    output_writer.writerow(row + ["Time Run"] + ["Processed?"])
                    outputfile.flush()
                    counter += 1
                    continue

                print("Processing: #" + str(counter) + " - " + row[columnIndex] + " Country: " + row[1])
                
                # Check if IP was proceeded x_days_ago, if yes, will skip calling
                file_skip = to_skip(row[0], "downloaded_vtresponse", x_days_ago)
                
                 # make dir to store API Responses
                if not os.path.exists("downloaded_vtresponse/" + dt_string):
                    os.makedirs("downloaded_vtresponse/" + dt_string)

                #Get an IP address Report
                if file_skip == 0:
                    r = requests.get("https://www.virustotal.com/api/v3/ip_addresses/"+row[0], headers={"x-apikey":API_KEY})
                    
                    ## Check status 200 = ok, 204 = exceeded, 400 = bad request, 403 = forbidden
                    # if status != 200, will break all processing
                    if (r.status_code != 200):
                        print("Status Code: ",r.status_code, "please take a look" )
                        output_writer.writerow(row + [datetime.datetime.now()] + ["Not Processed due to status_code: " + str(r.status_code)]) 
                        outputfile.flush()
                        break

                    r = r.json()
                    # inputting target_geo_country from excel into JSON
                    r['data']['attributes']['target_geo_country'] = row[1]
                    
                    with open("downloaded_vtresponse/" + dt_string + "/" + row[columnIndex] + ".json", "w") as outfile:

#                         outfile.write(r.text)
                        json_obj = json.dumps(r)
                        outfile.write(json_obj)

                    output_writer.writerow(row + [datetime.datetime.now()] + ["Processed"]) 

                    outputfile.flush()
                    time.sleep(16)

                
                else:
                    
                    output_writer.writerow(row + [datetime.datetime.now()] + ["Not Processed due to DUPLICATE in past "+ str(x_days_ago) + " days"] ) 
                    outputfile.flush()
                    
                
                counter += 1
                
    print("======= process_iplist() END ======= \n\n")
#                 time.sleep(16)


# check if file exist in folder_to_process during x_days_ago, returns 0 or 1
def to_skip(filename, folder_to_process, x_days_ago):
    
    now = datetime.datetime.now()
#     dt_string = now.strftime("%d%m%Y")
    dt_string = now.strftime("%Y%m%d")

    d = datetime.timedelta(days = x_days_ago)
#     deducted_date = (now - d).strftime("%d%m%Y")
    deducted_date = (now - d).strftime("%Y%m%d")
    to_skip = 0

    folders = os.listdir("downloaded_vtresponse")
    folders = os.listdir(folder_to_process)
    
#     print("deducted_date:", deducted_date)
    

    for folder in folders:

        if to_skip == 1:
            break

        # target folders within X days range
        
#         print("current folder:", folder)
#         print("folder >= deducted_date", folder>=deducted_date)
        if folder >= deducted_date:
            files_array = os.listdir("downloaded_vtresponse/" + folder)
#                         print(files_array)

            for file in files_array:
                filename_filetype = file.rsplit('.',1)
    #             print(filename_filedate)

                ## if filename == target THEN SKIP + WRITE A NOTE
                if filename == filename_filetype[0]:
                    print(f"file has been processed on {folder} which is <{x_days_ago} days ago, will skip API call")
                    to_skip = 1
                    break
        
    
    return to_skip


    #     print(os.listdir("downloaded_vtresponse/"+ folder))    

def process_json_folder(folder_to_process,json_template):
    
    print("======= process_json_folder() START =======")
    
    # Get Date + Time to input later
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")

    # Usual Folder: downloaded_vtresponse
    combined_df = pd.DataFrame()
    
    
    for filename in os.listdir(folder_to_process):
        f = os.path.join(folder_to_process, filename)
    
#         print("f:", f)
        # check if it is a file
        if os.path.isfile(f) and f[-5:]==".json":

            print("\n **** Processing:",f, "****")
            # Opening JSON file
            f = open(f)
#             print(f)

            # returns JSON object as
            # a dictionary
            data = json.load(f)
#             print(data)

            # load JSON template
            json_template = {
                            "ip_address": "",
                            "whois_date": "",
                            "last_analysis_date": "",
                            "reputation": "",
                            "last_analysis_stats": "",
                            "total_votes": "",
                            "as_owner": "",
                            "country": "",
                            "asn": "",
                            "image":"",
                            "processed_date":"",
                            "target_geo_country":""  ## input from original excel
                            }
        
            new_row = json_template
#             new_row = json_template()

            print("json_template: ", json_template)
            print("Fresh new_row from json_template: ", new_row)

            # populate fields in JSON template
            for key in new_row:    
#                 print("current key", key)

                try:
                    current_value = data['data']['attributes'][key]
                    
                    # replace epoch with legible date format for whois_date and last_analysis_date
                    if key[-4:] == "date":
                        to_zone = tz.gettz('Singapore')
                        date_time = datetime.datetime.fromtimestamp( current_value )  
#                         current_value = date_time.replace(tzinfo=to_zone)
                        date_time.replace(tzinfo=to_zone)
                        current_value = date_time
                        
            
                    new_row[key] = current_value

                except Exception as e: 
               
                    if key == "processed_date":
                        new_row[key] = now
                        print("new_row[key]:", now)
                    
                    elif key == "ip_address":
                        new_row[key] = data['data']['id']
                    
                    else:
                        print(key,"not found with exception:",e)

            print("new_row:", new_row)
            db.ip.insert_one(new_row)

            df_result = pd.json_normalize(new_row)
            
            combined_df = pd.concat([combined_df, df_result], ignore_index=True, sort=False)
    
    
#     print(combined_df)
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")
    
    combined_df.to_csv(folder_to_process + '/' + dt_string + '_parsed-combined.csv')
    
    print("======= process_json_folder() END ======= \n\n")



# Process the list of IPs (CSVs ok but IP must be x column in the list)
# (filename.csv, column, x_days_ago)
# process_iplist("ip", 0,7)
# process_iplist("filtered_sg_ip_list_day1", 0,7)
# process_iplist("filtered_sg_ip_list_day2", 0,7)
process_iplist("filtered_sg_ip_list", 0,7)



# Process the downloaded VT JSONs
# process_json_folder("downloaded_vtresponse_10Jan_combinedFull5k")
# process_json_folder("downloaded_vtresponse/28022023",json_template_ip)


print("completed")
exit(0)
# Out:
# ======= process_iplist() START =======
# Processing: #1 - 13.227.254.94 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2 - 13.227.254.99 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #3 - 23.200.24.43 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #4 - 17.248.164.108 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #5 - 13.33.100.61 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #6 - 52.76.228.161 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #7 - 173.194.22.169 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #8 - 18.142.201.37 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #9 - 192.166.246.143 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #10 - 203.116.175.163 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #11 - 13.228.90.32 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #12 - 52.76.40.178 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #13 - 121.7.89.176 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #14 - 31.13.68.1 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #15 - 13.33.88.116 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #16 - 3.1.152.102 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #17 - 23.49.60.129 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #18 - 96.16.116.196 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #19 - 101.32.104.177 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #20 - 17.248.154.11 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #21 - 54.192.150.89 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #22 - 23.52.113.101 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #23 - 74.125.68.155 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #24 - 52.76.243.108 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #25 - 157.240.13.55 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #26 - 23.210.250.80 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #27 - 43.132.80.22 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #28 - 13.33.28.118 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #29 - 121.6.48.26 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #30 - 23.195.152.208 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #31 - 184.27.122.40 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #32 - 52.98.71.50 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #33 - 23.15.110.65 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #34 - 23.49.60.202 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #35 - 51.79.164.247 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #36 - 188.42.147.32 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #37 - 3.1.123.42 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #38 - 23.59.80.33 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #39 - 51.79.222.34 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #40 - 23.215.7.84 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #41 - 23.210.250.107 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #42 - 175.41.187.144 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #43 - 54.179.75.107 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #44 - 54.169.104.250 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #45 - 116.87.186.130 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #46 - 157.240.7.53 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #47 - 13.33.100.94 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #48 - 23.75.23.57 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing:
Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #388 - 43.132.73.53 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #389 - 17.248.164.77 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #390 - 54.192.150.17 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #391 - 111.223.64.91 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #392 - 111.223.64.51 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #393 - 139.99.68.6 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #394 - 13.33.28.61 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #395 - 52.114.15.111 Country: SG
# ...
# Processing: #2630 - 13.33.33.13 Country: SG
# Processing: #2631 - 67.199.150.86 Country: SG
# Processing: #2632 - 23.200.24.91 Country: SG
# Processing: #2633 - 101.32.139.57 Country: SG
# Processing: #2634 - 203.116.175.154 Country: SG
# Processing: #2635 - 43.156.222.165 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2636 - 23.75.23.58 Country: SG
# Processing: #2637 - 172.217.194.99 Country: SG
# Processing: #2638 - 46.137.196.92 Country: SG
# Processing: #2639 - 104.119.104.25 Country: SG
# Processing: #2640 - 51.79.206.190 Country: SG
# Processing: #2641 - 203.117.34.146 Country: SG
# Processing: #2642 - 23.251.120.84 Country: SG
# Processing: #2643 - 23.50.85.221 Country: SG
# Processing: #2644 - 203.123.48.219 Country: SG
# Processing: #2645 - 13.33.88.121 Country: SG
# Processing: #2646 - 157.240.7.32 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2647 - 203.116.175.10 Country: SG
# Processing: #2648 - 18.141.109.184 Country: SG
# Processing: #2649 - 18.136.163.115 Country: SG
# Processing: #2650 - 13.35.22.210 Country: SG
# Processing: #2651 - 118.215.86.168 Country: SG
# Processing: #2652 - 111.65.100.17 Country: SG
# Processing: #2653 - 23.205.208.49 Country: SG
# Processing: #2654 - 13.214.111.70 Country: SG
# Processing: #2655 - 52.221.11.60 Country: SG
# Processing: #2656 - 94.74.88.100 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2657 - 23.210.250.161 Country: SG
# Processing: #2658 - 103.28.54.149 Country: SG
# Processing: #2659 - 129.226.3.47 Country: SG
# Processing: #2660 - 23.200.24.97 Country: SG
# Processing: #2661 - 52.221.118.118 Country: SG
# Processing: #2662 - 117.121.250.0 Country: SG
# Processing: #2663 - 104.89.119.136 Country: SG
# Processing: #2664 - 54.192.150.105 Country: SG
# Processing: #2665 - 61.8.33.40 Country: SG
# Processing: #2666 - 104.87.103.41 Country: SG
# Processing: #2667 - 40.126.35.64 Country: SG
# Processing: #2668 - 47.241.213.210 Country: SG
# Processing: #2669 - 111.223.64.82 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2670 - 150.109.90.118 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2671 - 18.136.141.185 Country: SG
# Processing: #2672 - 89.187.163.198 Country: SG
# Processing: #2673 - 156.225.96.77 Country: SG
# Processing: #2674 - 13.229.171.7 Country: SG
# Processing: #2675 - 47.246.58.225 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2676 - 43.132.81.28 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2677 - 43.156.86.39 Country: SG
# Processing: #2678 - 103.231.98.197 Country: SG
# Processing: #2679 - 74.125.200.136 Country: SG
# Processing: #2680 - 111.223.64.83 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2681 - 188.42.147.29 Country: SG
# Processing: #2682 - 17.248.164.74 Country: SG
# Processing: #2683 - 17.253.61.213 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2684 - 91.108.56.113 Country: SG
# Processing: #2685 - 104.69.107.2 Country: SG
# Processing: #2686 - 13.33.33.69 Country: SG
# Processing: #2687 - 17.248.164.106 Country: SG
# Processing: #2688 - 17.248.164.38 Country: SG
# Processing: #2689 - 18.138.147.249 Country: SG
# Processing: #2690 - 111.223.64.43 Country: SG
# Processing: #2691 - 89.207.22.76 Country: SG
# Processing: #2692 - 101.32.118.25 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2693 - 17.253.61.201 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2694 - 13.227.254.12 Country: SG
# Processing: #2695 - 161.117.125.35 Country: SG
# Processing: #2696 - 23.200.30.51 Country: SG
# Processing: #2697 - 23.202.134.27 Country: SG
# Processing: #2698 - 13.33.88.22 Country: SG
# Processing: #2699 - 54.251.140.206 Country: SG
# Processing: #2700 - 17.248.154.53 Country: SG
# Processing: #2701 - 203.118.0.112 Country: SG
# Processing: #2702 - 23.49.60.154 Country: SG
# Processing: #2703 - 111.223.64.74 Country: SG
# Processing: #2704 - 69.192.165.69 Country: SG
# Processing: #2705 - 18.136.31.89 Country: SG
# Processing: #2706 - 157.240.13.170 Country: SG
# Processing: #2707 - 13.228.143.90 Country: SG
# Processing: #2708 - 13.33.88.90 Country: SG
# Processing: #2709 - 43.132.80.30 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2710 - 17.248.164.68 Country: SG
# Processing: #2711 - 72.247.81.130 Country: SG
# Processing: #2712 - 23.47.190.90 Country: SG
# Processing: #2713 - 52.74.237.44 Country: SG
# Processing: #2714 - 54.192.150.53 Country: SG
# Processing: #2715 - 47.241.179.84 Country: SG
# Processing: #2716 - 23.50.90.106 Country: SG
# Processing: #2717 - 89.187.163.137 Country: SG
# Processing: #2718 - 23.200.24.80 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2719 - 17.248.154.34 Country: SG
# Processing: #2720 - 165.21.111.205 Country: SG
# Processing: #2721 - 13.33.100.225 Country: SG
# Processing: #2722 - 128.106.25.69 Country: SG
# Processing: #2723 - 106.10.186.201 Country: SG
# Processing: #2724 - 52.253.82.109 Country: SG
# Processing: #2725 - 51.79.205.157 Country: SG
# Processing: #2726 - 52.84.251.29 Country: SG
# Processing: #2727 - 101.33.27.25 Country: SG
# Processing: #2728 - 172.217.194.128 Country: SG
# Processing: #2729 - 184.27.122.155 Country: SG
# Processing: #2730 - 8.210.15.171 Country: SG
# Processing: #2731 - 18.142.165.68 Country: SG
# Processing: #2732 - 111.223.64.90 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2733 - 106.10.248.157 Country: SG
# Processing: #2734 - 52.84.251.81 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2735 - 43.132.80.54 Country: SG
# Processing: #2736 - 17.248.164.197 Country: SG
# Processing: #2737 - 17.248.164.83 Country: SG
# Processing: #2738 - 132.147.114.94 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2739 - 54.192.150.23 Country: SG
# Processing: #2740 - 13.228.250.207 Country: SG
# Processing: #2741 - 13.33.88.66 Country: SG
# Processing: #2742 - 89.187.163.196 Country: SG
# Processing: #2743 - 17.248.154.51 Country: SG
# Processing: #2744 - 43.132.81.29 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2745 - 52.84.228.218 Country: SG
# Processing: #2746 - 104.70.97.239 Country: SG
# Processing: #2747 - 13.33.88.102 Country: SG
# Processing: #2748 - 173.194.59.103 Country: SG
# Processing: #2749 - 18.136.63.255 Country: SG
# Processing: #2750 - 101.33.26.212 Country: SG
# Processing: #2751 - 157.240.7.48 Country: SG
# Processing: #2752 - 13.33.33.26 Country: SG
# Processing: #2753 - 17.253.61.205 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2754 - 13.228.176.211 Country: SG
# Processing: #2755 - 54.179.123.14 Country: SG
# Processing: #2756 - 23.200.24.64 Country: SG
# Processing: #2757 - 54.151.135.1 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2758 - 203.116.175.130 Country: SG
# Processing: #2759 - 172.217.194.139 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2760 - 23.36.49.158 Country: SG
# Processing: #2761 - 23.40.33.94 Country: SG
# Processing: #2762 - 157.240.235.61 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2763 - 54.169.13.63 Country: SG
# Processing: #2764 - 86.48.11.174 Country: SG
# Processing: #2765 - 3.1.140.95 Country: SG
# Processing: #2766 - 17.253.61.217 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2767 - 47.246.58.226 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2768 - 143.92.75.57 Country: SG
# Processing: #2769 - 157.240.7.20 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2770 - 23.59.168.51 Country: SG
# Processing: #2771 - 45.60.79.198 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2772 - 150.109.90.42 Country: SG
# Processing: #2773 - 43.132.73.34 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2774 - 18.136.152.184 Country: SG
# Processing: #2775 - 23.200.24.98 Country: SG
# Processing: #2776 - 23.200.24.57 Country: SG
# Processing: #2777 - 203.116.200.131 Country: SG
# Processing: #2778 - 43.132.81.247 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2779 - 116.0.81.229 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2780 - 124.155.222.185 Country: SG
# Processing: #2781 - 103.229.10.180 Country: SG
# Processing: #2782 - 72.247.81.163 Country: SG
# Processing: #2783 - 188.42.147.33 Country: SG
# Processing: #2784 - 17.248.164.36 Country: SG
# Processing: #2785 - 13.33.88.81 Country: SG
# Processing: #2786 - 54.169.85.42 Country: SG
# Processing: #2787 - 143.92.75.65 Country: SG
# Processing: #2788 - 42.60.143.143 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2789 - 111.65.100.1 Country: SG
# Processing: #2790 - 13.67.15.132 Country: SG
# Processing: #2791 - 74.125.200.132 Country: SG
# Processing: #2792 - 13.33.88.77 Country: SG
# Processing: #2793 - 13.33.88.127 Country: SG
# Processing: #2794 - 13.33.88.76 Country: SG
# Processing: #2795 - 119.28.121.173 Country: SG
# Processing: #2796 - 103.115.76.37 Country: SG
# Processing: #2797 - 203.117.34.145 Country: SG
# Processing: #2798 - 13.33.33.3 Country: SG
# Processing: #2799 - 71.18.1.240 Country: SG
# Processing: #2800 - 23.220.203.58 Country: SG
# Processing: #2801 - 143.92.88.1 Country: SG
# Processing: #2802 - 40.99.9.114 Country: SG
# Processing: #2803 - 104.81.138.123 Country: SG
# Processing: #2804 - 43.250.0.199 Country: SG
# Processing: #2805 - 184.31.7.73 Country: SG
# Processing: #2806 - 23.200.24.40 Country: SG
# Processing: #2807 - 104.215.145.31 Country: SG
# Processing: #2808 - 23.59.168.67 Country: SG
# Processing: #2809 - 46.137.209.137 Country: SG
# Processing: #2810 - 13.33.37.122 Country: SG
# Processing: #2811 - 17.248.164.114 Country: SG
# Processing: #2812 - 132.147.114.71 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2813 - 13.227.255.65 Country: SG
# Processing: #2814 - 91.108.56.174 Country: SG
# Processing: #2815 - 18.141.64.70 Country: SG
# Processing: #2816 - 13.33.92.161 Country: SG
# Processing: #2817 - 51.79.167.193 Country: SG
# Processing: #2818 - 13.250.252.64 Country: SG
# Processing: #2819 - 117.121.250.72 Country: SG
# Processing: #2820 - 74.125.130.156 Country: SG
# Processing: #2821 - 40.126.35.80 Country: SG
# Processing: #2822 - 43.134.57.13 Country: SG
# Processing: #2823 - 165.21.100.88 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2824 - 165.21.83.88 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2825 - 51.79.167.166 Country: SG
# Processing: #2826 - 13.213.128.128 Country: SG
# Processing: #2827 - 52.128.22.225 Country: SG
# Processing: #2828 - 23.5.165.149 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2829 - 23.205.208.234 Country: SG
# Processing: #2830 - 202.181.90.140 Country: SG
# Processing: #2831 - 156.59.238.1 Country: SG
# Processing: #2832 - 23.39.15.207 Country: SG
# Processing: #2833 - 119.13.160.161 Country: SG
# Processing: #2834 - 8.219.159.87 Country: SG
# Processing: #2835 - 52.84.251.119 Country: SG
# Processing: #2836 - 54.254.140.184 Country: SG
# Processing: #2837 - 52.84.226.216 Country: SG
# Processing: #2838 - 23.36.253.98 Country: SG
# Processing: #2839 - 124.155.222.24 Country: SG
# Processing: #2840 - 124.155.222.99 Country: SG
# file has been processed on 20230306 which is <7 days ago, will skip API call
# Processing: #2841 - 54.192.150.95 Country: SG
# Processing: #2842 - 18.139.155.41 Country: SG
# Processing: #2843 - 74.125.200.141 Country: SG
# Processing: #2844 - 150.109.90.125 Country: SG
# Processing: #2845 - 101.32.171.227 Country: SG
# Processing: #2846 - 184.87.193.143 Country: SG
# Processing: #2847 - 43.245.107.46 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2848 - 156.59.238.5 Country: SG
# Processing: #2849 - 23.220.203.32 Country: SG
# Processing: #2850 - 52.84.251.79 Country: SG
# Processing: #2851 - 184.50.107.216 Country: SG
# Processing: #2852 - 119.56.100.0 Country: SG
# Processing: #2853 - 139.99.62.128 Country: SG
# Processing: #2854 - 157.240.235.34 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2855 - 89.207.22.73 Country: SG
# Processing: #2856 - 172.224.26.154 Country: SG
# Processing: #2857 - 103.229.205.243 Country: SG
# Processing: #2858 - 116.0.81.214 Country: SG
# Processing: #2859 - 157.240.15.62 Country: SG
# Processing: #2860 - 172.224.26.155 Country: SG
# Processing: #2861 - 52.84.251.57 Country: SG
# Processing: #2862 - 129.227.82.187 Country: SG
# Processing: #2863 - 23.106.127.156 Country: SG
# Processing: #2864 - 157.240.13.55 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2865 - 51.79.164.83 Country: SG
# Processing: #2866 - 13.33.78.137 Country: SG
# Processing: #2867 - 52.84.251.70 Country: SG
# Processing: #2868 - 52.220.243.210 Country: SG
# Processing: #2869 - 54.192.150.99 Country: SG
# Processing: #2870 - 192.166.246.9 Country: SG
# Processing: #2871 - 52.84.251.34 Country: SG
# Processing: #2872 - 43.245.107.38 Country: SG
# Processing: #2873 - 13.76.153.29 Country: SG
# Processing: #2874 - 173.194.59.70 Country: SG
# Processing: #2875 - 150.109.16.124 Country: SG
# Processing: #2876 - 8.219.92.212 Country: SG
# file has been processed on 20230302 which is <7 days ago, will skip API call
# Processing: #2877 - 104.70.101.204 Country: SG
# Processing: #2878 - 23.50.94.4 Country: SG
# Processing: #2879 - 103.1.138.196 Country: SG
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2880 - 23.195.120.110 Country: SG
# Processing: #2881 - 159.138.87.106 Country: SG
# Processing: #2882 - 52.74.101.135 Country: SG
# Processing: #2883 - 17.248.164.232 Country: SG
# Processing: #2884 - 165.21.111.210 Country: SG
# Processing: #2885 - 52.77.93.65 Country: SG
# Processing: #2886 - 104.69.103.55 Country: SG
# Processing: #2887 - 172.217.194.101 Country: SG
# Processing: #2888 - 17.248.164.42 Country: SG
# Processing: #2889 - 129.227.82.149 Country: SG
# Processing: #2890 - 164.52.28.62 Country: SG
# Processing: #2891 - 20.198.162.78 Country: SG
# Processing: #2892 - 39.109.198.215 Country: SG
# Processing: #2893 - 13.33.88.5 Country: SG
# Processing: #2894 - 23.54.56.236 Country: SG
# Processing: #2895 - 54.151.200.67 Country: SG
# Processing: #2896 - 164.52.87.116 Country: SG
# Processing: #2897 - 52.76.64.92 Country: SG
# Processing: #2898 - 103.229.10.211 Country: SG
# Processing: #2899 - 54.254.189.170 Country: SG
# Processing: #2900 - 13.33.33.59 Country: SG
# Processing: #2901 - 47.241.65.164 Country: SG
# Processing: #2902 - 47.246.58.227 Country: SG
# file has been processed on 20230301 which is <7 days ago, will skip API call
# Processing: #2903 - 54.179.6.129 Country: SG
# Processing: #2904 - 54.254.167.180 Country: SG
# Processing: #2905 - 18.138.88.91 Country: SG
# Processing: #2906 - 124.155.222.17 Country: SG
# Processing: #2907 - 184.87.193.142 Country: SG
# Processing: #2908 - 23.49.60.184 Country: SG
# Processing: #2909 - 47.241.7.88 Country: SG
# ======= process_iplist() END =======
#
#
# completed

# %%
json_template_general = {
    
    "DNS": "", 
    "Whois": "",
    "whois_date": "", ## CONVERT FROM EPOCH TO USER FRIENDLY DATE
    "last_analysis_date": "",
    "creation_date": "",
    "reputation": "",
    "registrar": "",
    "last_analysis_stats": "",  ## SEPERATE INTO 5 COLUMNS?
    "last_https_certificate": "",
    "categories": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "download_archived_page":"",
    "image":"",
    "processed_date":""     ## OWN FIELD TO CHECK X+7 DAYS
    
    
}

# %%
json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

# %%
json_template_domain = {
    
    "DNS": "", 
    "Whois": "",
    "whois_date": "",
    "last_analysis_date": "",
    "creation_date": "",
    "reputation": "",
    "registrar": "",
    "last_analysis_stats": "",
    "last_https_certificate": "",
    "categories": "",
    "total_votes": "",
    "download_archived_page":"",
    "image":"",
    "processed_date":""
    
    
}

# %%
for key in json_template_ip:
    json_template_ip[key] = 1 
    
json_template_ip
# Out:
# {'whois_date': 1,
#  'last_analysis_date': 1,
#  'reputation': 1,
#  'last_analysis_stats': 1,
#  'total_votes': 1,
#  'as_owner': 1,
#  'country': 1,
#  'asn': 1,
#  'image': 1}

# %%
class ip_template:

    # class attribute
#     ip_address = ""
#     whois_date = ""
#     last_analysis_date = ""
#     reputation= ""
#     last_analysis_stats=""
#     total_votes= ""
#     as_owner=""
#     country= ""
#     asn=""
#     image=""
#     processed_date=""
#     target_geo_country="" 
    def __init__(self, roll_no, name, batch):
        self.roll_no = roll_no
        self.name = name
        self.batch = batch
    
new_row = ip_template('','','')
# new_row['sg']
# new_row.country="sg"
new_row_str =json.dumps(new_row.__dict__)
new_row_json = json.loads(new_row_json)
a
# new_row_json
# type(new_row_json)
# # create parrot1 object
# parrot1 = Parrot()
# parrot1.name = "Blu"
# parrot1.age = 10

# # create another object parrot2
# parrot2 = Parrot()
# parrot2.name = "Woo"
# parrot2.age = 15

# # access attributes
# print(f"{parrot1.name} is {parrot1.age} years old")
# print(f"{parrot2.name} is {parrot2.age} years old")
# Out:
# {'roll_no': '', 'name': '', 'batch': ''}

# %%
json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

# %%
import base64
import hashlib
import json
import requests
import time
import csv
import datetime
import os
import pandas as pd
from dateutil import tz
import pytz
from pymongo import MongoClient


def process_json_folder(folder_to_process,json_template):
    
    print("======= process_json_folder() START =======")
    
    # Get Date + Time to input later
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")

    # Usual Folder: downloaded_vtresponse
    combined_df = pd.DataFrame()
    
    
    for filename in os.listdir(folder_to_process):
        f = os.path.join(folder_to_process, filename)
    
#         print("f:", f)
        # check if it is a file
        if os.path.isfile(f) and f[-5:]==".json":

            print("\n **** Processing:",f, "****")
            # Opening JSON file
            f = open(f)
#             print(f)

            # returns JSON object as
            # a dictionary
            data = json.load(f)
#             print(data)

            # load JSON template
            json_template = {
                            "ip_address": "",
                            "whois_date": "",
                            "last_analysis_date": "",
                            "reputation": "",
                            "last_analysis_stats": "",
                            "total_votes": "",
                            "as_owner": "",
                            "country": "",
                            "asn": "",
                            "processed_date":"",
                            "target_geo_country":""  ## input from original excel
                            }
        
            new_row = json_template
#             new_row = json_template()

            print("json_template: ", json_template)
            print("Fresh new_row from json_template: ", new_row)

            # populate fields in JSON template
            for key in new_row:    
#                 print("current key", key)

                try:
                    current_value = data['data']['attributes'][key]
                    
                    # replace epoch with legible date format for whois_date and last_analysis_date
                    if key[-4:] == "date":
                        to_zone = tz.gettz('Singapore')
                        date_time = datetime.datetime.fromtimestamp( current_value )  
#                         current_value = date_time.replace(tzinfo=to_zone)
                        date_time.replace(tzinfo=to_zone)
                        current_value = date_time
                        
            
                    new_row[key] = current_value

                except Exception as e: 
               
                    if key == "processed_date":
                        new_row[key] = now
                        print("new_row[key]:", now)
                    
                    elif key == "ip_address":
                        new_row[key] = data['data']['id']
                    
                    else:
                        print(key,"not found with exception:",e)

            print("new_row:", new_row)
#             db.ip.insert_one(new_row)

            df_result = pd.json_normalize(new_row)
            
            combined_df = pd.concat([combined_df, df_result], ignore_index=True, sort=False)
    
    
#     print(combined_df)
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")
    
    combined_df.to_csv(folder_to_process + '/' + dt_string + '_parsed-combined.csv')
    
    print("======= process_json_folder() END ======= \n\n")



process_json_folder("downloaded_vtresponse/combined",json_template_ip)

# %%
# r.content

r.status_code
# site_response = str(r.content)
# print(site_response)
# Out:
# 200

# %%
x_days_ago = 7

["Not Processed due to DUPLICATE in past "+ str(x_days_ago) + " days"]
# Out:
# ['Not Processed due to DUPLICATE in past 7 days']
