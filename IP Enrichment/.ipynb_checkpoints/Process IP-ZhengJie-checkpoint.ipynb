# %% [markdown]
# ### Changelog
#
# - Separating **process_iplist()** output from VT calls to folders (todays_date)
# - changed output of **process_json()** FROM "_parsed-combined" to todays_date_parsed-combined in EACH RESPECTIVE FOLDER

# %% [markdown]
# ### Flow
#
# 1. User edits and feeds ip.csv
# 2. **process_iplist()** reads each and calls VT api
# 3. Responses are stored in **"downloaded_vtresponse"** and seperated into folders by **respective dates** (DDMMYYYY)
# 4. **process_json()** reads jsons in each folder and generates a compilation for that day in each folder

# %% [markdown]
# ### Questions / Todo List
#
# **Update**
#
# I have managed to get the scripts running from jupyter notebook but have the following questions
#
# (a) Receiving (via a web interface) either an individual or list of domais / IP addresses --> currently it's fed via CSV, should i create a front-end for people to upload their files?
#
# (b) Storing list of domains / IP address into a queue based list --> Is this the back-end of things? That is to say, this script runs in the back-end and whenever files come in from front-end it'll trigger the script?
#
# (c) Carryout enrichment --> Where does this "processed in the previous X days" come from? From what i understand, should i create a check such that when new information comes in, it will look at previous histories when the IP/Domain was checked, and continue / stop accordingly?
#
# (d) storing responses in disk and extracting subset into DB --> is there a specific subset you'd like? DB-wise I would prefer to try NoSQL as i have no experience with it!

# %%
import base64
import hashlib
import json
import requests
import time
import csv
import datetime
import os
import pandas as pd
from dateutil import tz
import pytz
from pymongo import MongoClient


json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

API_KEY = '0d9fdb6e32d74b9d12e3d894309531838c3aabe8d66b049fd3a7976fbedf2c68'  #@param  {type: "string"}
# API_KEY = '207349263f9c5edd176cc079fa8000a5ab912df7d9e91154842c08031658675d'  #@param  {type: "string"}



client = MongoClient('localhost',27017)
# db = client['d_ip_enrich']
db = client['filtered_sg_ip_list_day1']
    


def process_iplist(filename_to_process, columnIndex, x_days_ago):
    
    print("======= process_iplist() START =======")
    
    # TODO: Make generalised and incorporate timestamp in foldername
    now = datetime.datetime.now()
#     dt_string = now.strftime("%d%m%Y")
    dt_string = now.strftime("%Y%m%d")
    d = datetime.timedelta(days = x_days_ago)
#     deducted_date = (now - d).strftime("%d%m%Y")
    deducted_date = (now - d).strftime("%Y%m%d")
    
    with open(filename_to_process + ".csv", newline='') as inputfile:

        if not os.path.exists("downloaded_vtresponse"):
                os.makedirs("downloaded_vtresponse")

        with open(filename_to_process + "_tracker_" + dt_string + ".csv", 'w', newline='') as outputfile:
            
            ip_list = csv.reader(inputfile, delimiter=',')
            output_writer = csv.writer(outputfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

            counter = 0

            for row in ip_list:
                
                if counter == 0:
                    output_writer.writerow(row + ["Time Run"] + ["Processed?"])
                    outputfile.flush()
                    counter += 1
                    continue

                print("Processing: #" + str(counter) + " - " + row[columnIndex] + " Country: " + row[1])
                
                # Check if IP was proceeded x_days_ago, if yes, will skip calling
                file_skip = to_skip(row[0], "downloaded_vtresponse", x_days_ago)
                
                 # make dir to store API Responses
                if not os.path.exists("downloaded_vtresponse/" + dt_string):
                    os.makedirs("downloaded_vtresponse/" + dt_string)

                #Get an IP address Report
                if file_skip == 0:
                    r = requests.get("https://www.virustotal.com/api/v3/ip_addresses/"+row[0], headers={"x-apikey":API_KEY})
                    
                    ## Check status 200 = ok, 204 = exceeded, 400 = bad request, 403 = forbidden
                    # if status != 200, will break all processing
                    if (r.status_code != 200):
                        print("Status Code: ",r.status_code, "please take a look" )
                        output_writer.writerow(row + [datetime.datetime.now()] + ["Not Processed due to status_code: " + str(r.status_code)]) 
                        outputfile.flush()
                        break

                    r = r.json()
                    # inputting target_geo_country from excel into JSON
                    r['data']['attributes']['target_geo_country'] = row[1]
                    
                    with open("downloaded_vtresponse/" + dt_string + "/" + row[columnIndex] + ".json", "w") as outfile:

#                         outfile.write(r.text)
                        json_obj = json.dumps(r)
                        outfile.write(json_obj)

                    output_writer.writerow(row + [datetime.datetime.now()] + ["Processed"]) 

                    outputfile.flush()
                    time.sleep(16)

                
                else:
                    
                    output_writer.writerow(row + [datetime.datetime.now()] + ["Not Processed due to DUPLICATE in past "+ str(x_days_ago) + " days"] ) 
                    outputfile.flush()
                    
                
                counter += 1
                
    print("======= process_iplist() END ======= \n\n")
#                 time.sleep(16)


# check if file exist in folder_to_process during x_days_ago, returns 0 or 1
def to_skip(filename, folder_to_process, x_days_ago):
    
    now = datetime.datetime.now()
#     dt_string = now.strftime("%d%m%Y")
    dt_string = now.strftime("%Y%m%d")

    d = datetime.timedelta(days = x_days_ago)
#     deducted_date = (now - d).strftime("%d%m%Y")
    deducted_date = (now - d).strftime("%Y%m%d")
    to_skip = 0

    folders = os.listdir("downloaded_vtresponse")
    folders = os.listdir(folder_to_process)
    
    print("deducted_date:", deducted_date)
    

    for folder in folders:

        if to_skip == 1:
            break

        # target folders within X days range
        
        print("current folder:", folder)
        print("folder >= deducted_date", folder>=deducted_date)
        if folder >= deducted_date:
            files_array = os.listdir("downloaded_vtresponse/" + folder)
#                         print(files_array)

            for file in files_array:
                filename_filetype = file.rsplit('.',1)
    #             print(filename_filedate)

                ## if filename == target THEN SKIP + WRITE A NOTE
                if filename == filename_filetype[0]:
                    print(f"file has been processed on {folder} which is <{x_days_ago} days ago, will skip API call")
                    to_skip = 1
                    break
        
    
    return to_skip


    #     print(os.listdir("downloaded_vtresponse/"+ folder))    

def process_json_folder(folder_to_process,json_template):
    
    print("======= process_json_folder() START =======")
    
    # Get Date + Time to input later
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")

    # Usual Folder: downloaded_vtresponse
    combined_df = pd.DataFrame()
    
    
    for filename in os.listdir(folder_to_process):
        f = os.path.join(folder_to_process, filename)
    
#         print("f:", f)
        # check if it is a file
        if os.path.isfile(f) and f[-5:]==".json":

            print("\n **** Processing:",f, "****")
            # Opening JSON file
            f = open(f)
#             print(f)

            # returns JSON object as
            # a dictionary
            data = json.load(f)
#             print(data)

            # load JSON template
            json_template = {
                            "ip_address": "",
                            "whois_date": "",
                            "last_analysis_date": "",
                            "reputation": "",
                            "last_analysis_stats": "",
                            "total_votes": "",
                            "as_owner": "",
                            "country": "",
                            "asn": "",
                            "image":"",
                            "processed_date":"",
                            "target_geo_country":""  ## input from original excel
                            }
        
            new_row = json_template
#             new_row = json_template()

            print("json_template: ", json_template)
            print("Fresh new_row from json_template: ", new_row)

            # populate fields in JSON template
            for key in new_row:    
#                 print("current key", key)

                try:
                    current_value = data['data']['attributes'][key]
                    
                    # replace epoch with legible date format for whois_date and last_analysis_date
                    if key[-4:] == "date":
                        to_zone = tz.gettz('Singapore')
                        date_time = datetime.datetime.fromtimestamp( current_value )  
#                         current_value = date_time.replace(tzinfo=to_zone)
                        date_time.replace(tzinfo=to_zone)
                        current_value = date_time
                        
            
                    new_row[key] = current_value

                except Exception as e: 
               
                    if key == "processed_date":
                        new_row[key] = now
                        print("new_row[key]:", now)
                    
                    elif key == "ip_address":
                        new_row[key] = data['data']['id']
                    
                    else:
                        print(key,"not found with exception:",e)

            print("new_row:", new_row)
            db.ip.insert_one(new_row)

            df_result = pd.json_normalize(new_row)
            
            combined_df = pd.concat([combined_df, df_result], ignore_index=True, sort=False)
    
    
#     print(combined_df)
    now = datetime.datetime.now(pytz.timezone("Singapore"))
    dt_string = now.strftime("%d%m%Y")
    
    combined_df.to_csv(folder_to_process + '/' + dt_string + '_parsed-combined.csv')
    
    print("======= process_json_folder() END ======= \n\n")



# Process the list of IPs (CSVs ok but IP must be x column in the list)
# (filename.csv, column, x_days_ago)
# process_iplist("ip", 0,7)
# process_iplist("filtered_sg_ip_list_day1", 0,7)
# process_iplist("filtered_sg_ip_list_day2", 0,7)
process_iplist("filtered_sg_ip_list", 0,7)



# Process the downloaded VT JSONs
# process_json_folder("downloaded_vtresponse_10Jan_combinedFull5k")
# process_json_folder("downloaded_vtresponse/28022023",json_template_ip)


print("completed")
exit(0)
# Out:
# ======= process_iplist() START =======
# Processing: #1 - 13.227.254.94 Country: SG
# deducted_date: 20230223
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #2 - 13.227.254.99 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #3 - 23.200.24.43 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #4 - 17.248.164.108 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #5 - 13.33.100.61 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #6 - 52.76.228.161 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #7 - 173.194.22.169 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #8 - 18.142.201.37 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #9 - 192.166.246.143 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #10 - 203.116.175.163 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #11 - 13.228.90.32 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #12 - 52.76.40.178 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #13 - 121.7.89.176 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #14 - 31.13.68.1 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #15 - 13.33.88.116 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #16 - 3.1.152.102 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #17 - 23.49.60.129 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #18 - 96.16.116.196 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #19 - 101.32.104.177 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #20 - 17.248.154.11 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #21 - 54.192.150.89 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #22 - 23.52.113.101 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #23 - 74.125.68.155 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #24 - 52.76.243.108 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #25 - 157.240.13.55 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #26 - 23.210.250.80 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #27 - 43.132.80.22 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #28 - 13.33.28.118 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #29 - 121.6.48.26 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #30 - 23.195.152.208 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #31 - 184.27.122.40 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #32 - 52.98.71.50 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #33 - 23.15.110.65 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #34 - 23.49.60.202 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #35 - 51.79.164.247 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #36 - 188.42.147.32 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #37 - 3.1.123.42 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #38 - 23.59.80.33 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #39 - 51.79.222.34 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #40 - 23.215.7.84 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #41 - 23.210.250.107 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #42 - 175.41.187.144 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #43 - 54.179.75.107 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #44 - 54.169.104.250 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #45 - 116.87.186.130 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #46 - 157.240.7.53 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #47 - 13.33.100.94 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #48 - 23.75.23.57 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #49 - 52.114.15.181 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #50 - 74.125.171.73 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #51 - 203.116.175.171 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #52 - 54.192.150.44 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #53 - 18.136.86.75 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #54 - 52.84.251.9 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #55 - 203.116.175.32 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #56 - 104.69.163.61 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #57 - 180.87.173.16 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #58 - 17.248.154.17 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #59 - 54.192.150.12 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #60 - 13.33.88.87 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #61 - 51.79.165.204 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #62 - 104.69.163.60 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #63 - 104.69.32.93 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #64 - 17.248.164.45 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #65 - 52.77.133.180 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #66 - 23.220.203.115 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #67 - 89.187.163.193 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #68 - 52.220.33.166 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #69 - 54.251.192.147 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #70 - 23.54.56.156 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #71 - 3.1.149.134 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #72 - 104.83.197.140 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #73 - 23.73.13.201 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #74 - 167.71.195.165 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #75 - 23.59.80.224 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #76 - 52.74.88.135 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #77 - 129.227.82.185 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #78 - 89.187.162.21 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #79 - 51.79.130.26 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #80 - 17.248.154.3 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #81 - 43.132.80.244 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #82 - 17.248.164.12 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #83 - 54.192.150.36 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #84 - 165.21.111.145 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #85 - 20.190.163.29 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #86 - 23.5.165.18 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #87 - 3.1.15.205 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #88 - 17.248.164.82 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #89 - 101.33.26.124 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #90 - 103.151.126.72 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #91 - 103.231.98.195 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #92 - 13.33.88.101 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #93 - 18.142.135.199 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #94 - 150.109.90.54 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #95 - 116.87.131.164 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #96 - 52.98.90.178 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #97 - 17.248.164.47 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #98 - 116.14.207.20 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #99 - 184.27.122.48 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #100 - 52.84.251.24 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #101 - 17.253.61.220 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #102 - 101.33.26.140 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #103 - 13.227.254.35 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #104 - 31.13.68.34 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #105 - 103.1.138.196 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #106 - 13.35.18.228 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #107 - 117.121.250.156 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #108 - 40.99.10.66 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #109 - 54.192.151.123 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #110 - 20.212.128.44 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #111 - 52.220.200.42 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #112 - 54.192.150.58 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #113 - 3.0.25.35 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #114 - 13.33.33.53 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #115 - 13.33.100.30 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #116 - 23.39.12.48 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #117 - 203.117.35.17 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #118 - 40.119.249.228 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #119 - 72.247.81.153 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #120 - 23.5.165.11 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #121 - 23.205.209.121 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #122 - 20.212.96.199 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #123 - 165.21.111.147 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #124 - 74.125.200.139 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #125 - 54.169.248.42 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #126 - 192.166.246.41 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #127 - 203.116.175.128 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #128 - 23.50.92.154 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #129 - 74.125.68.154 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #130 - 18.140.39.47 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #131 - 23.36.252.78 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #132 - 150.109.90.59 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #133 - 172.224.26.138 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #134 - 13.33.33.41 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #135 - 84.17.39.169 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #136 - 51.79.204.59 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #137 - 138.199.60.185 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #138 - 203.116.175.170 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #139 - 54.192.150.67 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #140 - 157.240.13.1 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #141 - 58.182.177.133 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #142 - 52.221.62.54 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #143 - 23.205.208.247 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #144 - 104.70.101.66 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #145 - 54.192.150.77 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #146 - 161.117.96.24 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #147 - 18.138.223.207 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #148 - 13.251.71.45 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #149 - 204.246.164.112 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #150 - 185.200.117.142 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #151 - 52.98.33.130 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #152 - 23.5.165.146 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #153 - 52.84.251.50 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #154 - 52.74.243.124 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #155 - 121.7.140.29 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #156 - 43.132.81.247 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# ...
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #547 - 13.33.100.113 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #548 - 118.215.87.103 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #549 - 3.0.71.181 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #550 - 3.0.114.63 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #551 - 13.227.254.127 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #552 - 43.156.10.157 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #553 - 23.108.101.160 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #554 - 184.31.4.239 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #555 - 203.117.89.32 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #556 - 13.227.254.80 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #557 - 23.199.241.249 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #558 - 23.106.249.200 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #559 - 52.221.48.28 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #560 - 54.192.150.129 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #561 - 101.33.26.117 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #562 - 13.251.133.111 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #563 - 203.205.155.79 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #564 - 156.146.56.89 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #565 - 132.147.114.72 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #566 - 104.103.146.82 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #567 - 101.33.27.9 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #568 - 129.226.2.109 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #569 - 23.195.121.65 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #570 - 173.194.22.40 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #571 - 118.200.43.119 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #572 - 23.47.190.82 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #573 - 184.31.5.52 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #574 - 23.200.24.50 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #575 - 121.7.52.95 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #576 - 111.223.64.18 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #577 - 129.226.3.42 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #578 - 42.61.136.253 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #579 - 17.248.154.20 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #580 - 17.248.154.9 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #581 - 104.69.46.40 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #582 - 121.6.48.26 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #583 - 103.229.205.242 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #584 - 52.76.244.101 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #585 - 156.59.238.4 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #586 - 142.251.88.74 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #587 - 163.171.211.51 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #588 - 106.10.236.40 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #589 - 172.224.26.143 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #590 - 51.79.223.25 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #591 - 101.32.107.74 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# file has been processed on 20230228 which is <7 days ago, will skip API call
# Processing: #592 - 17.248.164.103 Country: SG
# deducted_date: 20230223
# current folder: 02032023
# folder >= deducted_date False
# current folder: 20230222
# folder >= deducted_date False
# current folder: 20230228
# folder >= deducted_date True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 273>()
#     264     print("======= process_json_folder() END ======= \n\n")
#     268 # Process the list of IPs (CSVs ok but IP must be x column in the list)
#     269 # (filename.csv, column, x_days_ago)
#     270 # process_iplist("ip", 0,7)
#     271 # process_iplist("filtered_sg_ip_list_day1", 0,7)
#     272 # process_iplist("filtered_sg_ip_list_day2", 0,7)
# --> 273 process_iplist("filtered_sg_ip_list", 0,7)
#     277 # Process the downloaded VT JSONs
#     278 # process_json_folder("downloaded_vtresponse_10Jan_combinedFull5k")
#     279 # process_json_folder("downloaded_vtresponse/28022023",json_template_ip)
#     282 print("completed")
#
# Input In [4], in process_iplist(filename_to_process, columnIndex, x_days_ago)
#      73 print("Processing: #" + str(counter) + " - " + row[columnIndex] + " Country: " + row[1])
#      75 # Check if IP was proceeded x_days_ago, if yes, will skip calling
# ---> 76 file_skip = to_skip(row[0], "downloaded_vtresponse", x_days_ago)
#      78  # make dir to store API Responses
#      79 if not os.path.exists("downloaded_vtresponse/" + dt_string):
#
# Input In [4], in to_skip(filename, folder_to_process, x_days_ago)
#     148         print("folder >= deducted_date", folder>=deducted_date)
#     149         if folder >= deducted_date:
# --> 150             files_array = os.listdir("downloaded_vtresponse/" + folder)
#     151 #                         print(files_array)
#     153             for file in files_array:
#
# KeyboardInterrupt:

# %%
json_template_general = {
    
    "DNS": "", 
    "Whois": "",
    "whois_date": "", ## CONVERT FROM EPOCH TO USER FRIENDLY DATE
    "last_analysis_date": "",
    "creation_date": "",
    "reputation": "",
    "registrar": "",
    "last_analysis_stats": "",  ## SEPERATE INTO 5 COLUMNS?
    "last_https_certificate": "",
    "categories": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "download_archived_page":"",
    "image":"",
    "processed_date":""     ## OWN FIELD TO CHECK X+7 DAYS
    
    
}

# %%
json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

# %%
json_template_domain = {
    
    "DNS": "", 
    "Whois": "",
    "whois_date": "",
    "last_analysis_date": "",
    "creation_date": "",
    "reputation": "",
    "registrar": "",
    "last_analysis_stats": "",
    "last_https_certificate": "",
    "categories": "",
    "total_votes": "",
    "download_archived_page":"",
    "image":"",
    "processed_date":""
    
    
}

# %%
for key in json_template_ip:
    json_template_ip[key] = 1 
    
json_template_ip
# Out:
# {'whois_date': 1,
#  'last_analysis_date': 1,
#  'reputation': 1,
#  'last_analysis_stats': 1,
#  'total_votes': 1,
#  'as_owner': 1,
#  'country': 1,
#  'asn': 1,
#  'image': 1}

# %%
class ip_template:

    # class attribute
#     ip_address = ""
#     whois_date = ""
#     last_analysis_date = ""
#     reputation= ""
#     last_analysis_stats=""
#     total_votes= ""
#     as_owner=""
#     country= ""
#     asn=""
#     image=""
#     processed_date=""
#     target_geo_country="" 
    def __init__(self, roll_no, name, batch):
        self.roll_no = roll_no
        self.name = name
        self.batch = batch
    
new_row = ip_template('','','')
# new_row['sg']
# new_row.country="sg"
new_row_str =json.dumps(new_row.__dict__)
new_row_json = json.loads(new_row_json)
a
# new_row_json
# type(new_row_json)
# # create parrot1 object
# parrot1 = Parrot()
# parrot1.name = "Blu"
# parrot1.age = 10

# # create another object parrot2
# parrot2 = Parrot()
# parrot2.name = "Woo"
# parrot2.age = 15

# # access attributes
# print(f"{parrot1.name} is {parrot1.age} years old")
# print(f"{parrot2.name} is {parrot2.age} years old")
# Out:
# {'roll_no': '', 'name': '', 'batch': ''}

# %%
json_template_ip = {
    
    "ip_address": "",
    "whois_date": "",
    "last_analysis_date": "",
    "reputation": "",
    "last_analysis_stats": "",
    "total_votes": "",
    "as_owner": "",
    "country": "",
    "asn": "",
    "image":"",
    "processed_date":"",
    "target_geo_country":""  ## input from original excel
       
}

# %%
import base64
import hashlib
import json
import requests
import time
import csv
import datetime
import os
import pandas as pd
from dateutil import tz
import pytz
from pymongo import MongoClient

API_KEY = '207349263f9c5edd176cc079fa8000a5ab912df7d9e91154842c08031658675d'  #@param  {type: "string"}
r = requests.get("https://www.virustotal.com/api/v3/ip_addresses/1.1.1.1", headers={"x-apikey":API_KEY})

# %%
# r.content

r.status_code
# site_response = str(r.content)
# print(site_response)
# Out:
# 200

# %%
x_days_ago = 7

["Not Processed due to DUPLICATE in past "+ str(x_days_ago) + " days"]
# Out:
# ['Not Processed due to DUPLICATE in past 7 days']
